# %%
#requires installing adafruit-circuitpython-bmp280 library and gpiozero; implementation of plotting to be added
#Data: Includes full range of fan capacity (30> and <20 degrees Celcius responses)

from time import sleep
import board
import adafruit_bmp280
from gpiozero import Motor
from matplotlib import pyplot as plt

i2c = board.I2C()
bmp280 = adafruit_bmp280.Adafruit_BMP280_I2C(i2c,address=0x76)
mot = Motor(forward = 18, backward = 19, enable = 17, pwm = True)
x=[]
y=[]

bmp280.sea_level_pressure = 1013.25

def get_temp():
    try:
        return bmp280.temperature
    except OSError:
        print("Sensor glitch")
        sleep(.1)
        return None

def loop():
    count = 0
    while True:
        print("\nTemperature: %0.1f C"%bmp280.temperature)
        print("Pressure:%0.1f hPa" % bmp280.pressure)
        print("Altitude = %0.2f meters" % bmp280.altitude)
        if bmp280.temperature > 30:
            mot.forward(1)
        elif bmp280.temperature >25:
            mot.forward(.8)
        elif bmp280.temperature > 20:
            mot.forward(1)
            sleep(.2)
            mot.forward(.5)
        else:
            mot.forward(0)
        temp = get_temp()
        if temp is None:
            continue
        y.append(temp)
        x.append(count)
        sleep(2)
        count+=2

if __name__ == "__main__":
    try:
        loop()
    except KeyboardInterrupt:
        print("end")
        plt.plot(x,y)
        plt.xlabel("time (s)")
        plt.ylabel("temperature (c)")
        plt.title("Temperature as a function of time")
        plt.show()
        i2c.deinit()
        mot.close()
# Out:
# Temperature: 19.5 C
# Pressure:1010.9 hPa
# Altitude = 19.38 meters
#
# Temperature: 19.6 C
# Pressure:1010.9 hPa
# Altitude = 19.42 meters
#
# Temperature: 19.5 C
# Pressure:1010.9 hPa
# Altitude = 19.32 meters
#
# Temperature: 21.8 C
# Pressure:1011.0 hPa
# Altitude = 19.31 meters
#
# Temperature: 21.1 C
# Pressure:1010.9 hPa
# Altitude = 19.07 meters
#
# Temperature: 20.8 C
# Pressure:1010.9 hPa
# Altitude = 19.52 meters
#
# Temperature: 20.7 C
# Pressure:1010.9 hPa
# Altitude = 19.53 meters
#
# Temperature: 20.5 C
# Pressure:1010.9 hPa
# Altitude = 19.48 meters
#
# Temperature: 20.5 C
# Pressure:1011.0 hPa
# Altitude = 19.14 meters
#
# Temperature: 22.7 C
# Pressure:1010.9 hPa
# Altitude = 19.37 meters
#
# Temperature: 25.5 C
# Pressure:1011.0 hPa
# Altitude = 19.09 meters
#
# Temperature: 26.9 C
# Pressure:1011.0 hPa
# Altitude = 19.05 meters
#
# Temperature: 27.7 C
# Pressure:1011.0 hPa
# Altitude = 18.83 meters
#
# Temperature: 28.4 C
# Pressure:1011.0 hPa
# Altitude = 18.20 meters
#
# Temperature: 28.9 C
# Pressure:1011.0 hPa
# Altitude = 18.65 meters
#
# Temperature: 29.4 C
# Pressure:1011.0 hPa
# Altitude = 18.40 meters
#
# Temperature: 29.9 C
# Pressure:1011.1 hPa
# Altitude = 18.21 meters
#
# Temperature: 30.2 C
# Pressure:1011.1 hPa
# Altitude = 18.22 meters
#
# Temperature: 30.5 C
# Pressure:1011.1 hPa
# Altitude = 18.33 meters
#
# Temperature: 29.9 C
# Pressure:1011.1 hPa
# Altitude = 18.36 meters
#
# Temperature: 29.1 C
# Pressure:1011.0 hPa
# Altitude = 18.80 meters
#
# Temperature: 28.4 C
# Pressure:1011.0 hPa
# Altitude = 18.93 meters
#
# Temperature: 27.7 C
# Pressure:1011.0 hPa
# Altitude = 18.75 meters
#
# Temperature: 27.2 C
# Pressure:1011.0 hPa
# Altitude = 18.83 meters
#
# Temperature: 26.7 C
# Pressure:1010.9 hPa
# Altitude = 19.32 meters
#
# Temperature: 26.2 C
# Pressure:1011.0 hPa
# Altitude = 19.22 meters
#
# Temperature: 25.8 C
# Pressure:1011.0 hPa
# Altitude = 18.96 meters
#
# Temperature: 25.5 C
# Pressure:1011.0 hPa
# Altitude = 18.81 meters
#
# Temperature: 25.1 C
# Pressure:1010.9 hPa
# Altitude = 19.01 meters
#
# Temperature: 24.8 C
# Pressure:1011.0 hPa
# Altitude = 19.05 meters
#
# Temperature: 24.5 C
# Pressure:1010.9 hPa
# Altitude = 19.61 meters
#
# Temperature: 24.2 C
# Pressure:1010.9 hPa
# Altitude = 19.57 meters
#
# Temperature: 24.0 C
# Pressure:1010.9 hPa
# Altitude = 19.48 meters
#
# Temperature: 23.8 C
# Pressure:1011.0 hPa
# Altitude = 18.98 meters
#
# Temperature: 23.5 C
# Pressure:1011.0 hPa
# Altitude = 18.85 meters
#
# Temperature: 23.3 C
# Pressure:1010.9 hPa
# Altitude = 19.35 meters
#
# Temperature: 23.1 C
# Pressure:1010.9 hPa
# Altitude = 19.65 meters
#
# Temperature: 22.9 C
# Pressure:1010.9 hPa
# Altitude = 19.73 meters
#
# Temperature: 22.8 C
# Pressure:1010.9 hPa
# Altitude = 19.66 meters
#
# Temperature: 22.7 C
# Pressure:1011.0 hPa
# Altitude = 19.03 meters
#
# Temperature: 22.5 C
# Pressure:1010.9 hPa
# Altitude = 19.10 meters
#
# Temperature: 22.4 C
# Pressure:1010.9 hPa
# Altitude = 19.41 meters
#
# Temperature: 22.3 C
# Pressure:1010.9 hPa
# Altitude = 19.74 meters
#
# Temperature: 22.2 C
# Pressure:1010.9 hPa
# Altitude = 19.96 meters
#
# Temperature: 22.1 C
# Pressure:1010.9 hPa
# Altitude = 19.26 meters
#
# Temperature: 22.0 C
# Pressure:1010.9 hPa
# Altitude = 19.22 meters
#
# Temperature: 21.9 C
# Pressure:1011.0 hPa
# Altitude = 19.33 meters
#
# Temperature: 21.8 C
# Pressure:1010.9 hPa
# Altitude = 19.65 meters
#
# Temperature: 21.7 C
# Pressure:1010.9 hPa
# Altitude = 19.34 meters
#
# Temperature: 21.6 C
# Pressure:1010.9 hPa
# Altitude = 19.37 meters
#
# Temperature: 21.5 C
# Pressure:1011.0 hPa
# Altitude = 18.94 meters
#
# Temperature: 21.4 C
# Pressure:1010.9 hPa
# Altitude = 19.31 meters
#
# Temperature: 21.3 C
# Pressure:1010.9 hPa
# Altitude = 19.52 meters
#
# Temperature: 21.2 C
# Pressure:1010.9 hPa
# Altitude = 19.53 meters
#
# Temperature: 21.2 C
# Pressure:1010.9 hPa
# Altitude = 19.38 meters
#
# Temperature: 21.1 C
# Pressure:1010.9 hPa
# Altitude = 19.42 meters
#
# Temperature: 21.1 C
# Pressure:1010.9 hPa
# Altitude = 19.54 meters
#
# Temperature: 21.0 C
# Pressure:1010.9 hPa
# Altitude = 19.69 meters
#
# Temperature: 20.9 C
# Pressure:1010.9 hPa
# Altitude = 19.47 meters
#
# Temperature: 20.9 C
# Pressure:1010.9 hPa
# Altitude = 19.14 meters
#
# Temperature: 20.9 C
# Pressure:1010.9 hPa
# Altitude = 19.25 meters
#
# Temperature: 20.8 C
# Pressure:1010.9 hPa
# Altitude = 19.77 meters
#
# Temperature: 20.7 C
# Pressure:1010.9 hPa
# Altitude = 19.68 meters
#
# Temperature: 20.7 C
# Pressure:1010.9 hPa
# Altitude = 19.82 meters
#
# Temperature: 20.7 C
# Pressure:1010.9 hPa
# Altitude = 19.48 meters
#
# Temperature: 20.6 C
# Pressure:1010.9 hPa
# Altitude = 19.70 meters
#
# Temperature: 20.5 C
# Pressure:1010.9 hPa
# Altitude = 19.83 meters
#
# Temperature: 20.5 C
# Pressure:1010.9 hPa
# Altitude = 20.03 meters
#
# Temperature: 20.5 C
# Pressure:1010.9 hPa
# Altitude = 19.91 meters
#
# Temperature: 20.5 C
# Pressure:1010.9 hPa
# Altitude = 19.42 meters
#
# Temperature: 20.4 C
# Pressure:1010.9 hPa
# Altitude = 19.28 meters
#
# Temperature: 20.4 C
# Pressure:1010.9 hPa
# Altitude = 19.49 meters
#
# Temperature: 20.3 C
# Pressure:1010.9 hPa
# Altitude = 19.69 meters
#
# Temperature: 20.3 C
# Pressure:1010.9 hPa
# Altitude = 19.64 meters
#
# Temperature: 20.3 C
# Pressure:1010.9 hPa
# Altitude = 19.29 meters
#
# Temperature: 20.3 C
# Pressure:1010.9 hPa
# Altitude = 19.04 meters
#
# Temperature: 20.2 C
# Pressure:1010.9 hPa
# Altitude = 19.25 meters
#
# Temperature: 20.2 C
# Pressure:1010.9 hPa
# Altitude = 19.66 meters
#
# Temperature: 20.2 C
# Pressure:1010.9 hPa
# Altitude = 19.57 meters
#
# Temperature: 20.2 C
# Pressure:1010.9 hPa
# Altitude = 19.48 meters
#
# Temperature: 20.2 C
# Pressure:1010.9 hPa
# Altitude = 19.22 meters
#
# Temperature: 20.2 C
# Pressure:1010.9 hPa
# Altitude = 19.50 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 19.46 meters
#
# Temperature: 20.1 C
# Pressure:1010.8 hPa
# Altitude = 19.77 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 19.74 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 19.58 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 19.52 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 19.62 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 20.16 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.60 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.42 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 20.02 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 19.84 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.59 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.35 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.60 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 20.09 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.87 meters
#
# Temperature: 20.0 C
# Pressure:1011.0 hPa
# Altitude = 19.32 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.70 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.55 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.92 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.74 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.67 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.55 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.90 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 20.08 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 19.77 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.51 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.76 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 19.70 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 20.14 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 19.98 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.48 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.92 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 20.11 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 20.25 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.81 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.35 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.68 meters
#
# Temperature: 19.9 C
# Pressure:1010.8 hPa
# Altitude = 20.10 meters
#
# Temperature: 19.9 C
# Pressure:1010.9 hPa
# Altitude = 19.96 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.68 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.30 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.61 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 20.18 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.71 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.66 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 20.18 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 19.97 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.88 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.61 meters
#
# Temperature: 20.0 C
# Pressure:1010.9 hPa
# Altitude = 19.62 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 20.10 meters
#
# Temperature: 20.0 C
# Pressure:1010.8 hPa
# Altitude = 19.97 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 20.08 meters
#
# Temperature: 20.1 C
# Pressure:1010.9 hPa
# Altitude = 19.77 meters
# end
